# %%
# !pwd
# Out:
# /projects/0fc15983-dd6f-4ad6-b187-1f86d3a8f89d/ENSP-439-Examples/ETC

# %%
# %matplotlib inline
import pandas as pd

etc = pd.read_csv('../../data-cleaning-verification/ETC/cleaned/ETC-QCLCD-2016-2017.csv', index_col=0, parse_dates=True)
# plot how much warmer the building is than outside

etc['deltaT'] = etc['Temperature'] - etc['Outside Temp (C)']
etc['deltaT']['2016-11-01':'2017-02-28'].plot()

#(etc['deltaT']['2016-12-01':'2017-01-01'].cumsum()/24).plot()

# %%
etc['Temperature']['2016-11-01':'2017-02-28'].plot()

# %%
(etc['deltaT']['2016-11-01':'2017-02-28'].cumsum()/24).plot()

# %%
degree_hours = etc['deltaT']['2016-11-01':'2017-02-28'].sum()

# %%
degree_hours
# Out:
# 34468.00468541033

# %%
therms_observed = 333
btu_observed = therms_observed * 10**5
UA_inferred = btu_observed / degree_hours

# %%
print('UA inferred', UA_inferred )
# Out:
# UA inferred 966.1133652478375

# %%
# note that this appears higher than the estimate for the walls and ceiling.
# how much would including the floor move this?
