# %%
import pandas as pd

# %%
Nichols = pd.read_csv('Nichols_clean.csv', parse_dates = True, index_col = 0)

# %%
Nichols.columns
# Out:
# Index([u'Demand(BTU/h)'], dtype='object')

# %%
Nichols
# Out:
#                      Demand(BTU/h)
# TimeStamp
# 2016-10-13 07:00:00        0.00000
# 2016-10-13 08:00:00        0.00000
# 2016-10-13 09:00:00        0.00000
# 2016-10-13 10:00:00        0.00000
# 2016-10-13 11:00:00        0.00000
# 2016-10-13 12:00:00   165950.19400
# 2016-10-13 13:00:00   292492.73440
# 2016-10-13 14:00:00   291043.11720
# 2016-10-13 15:00:00   282748.24870
# 2016-10-13 16:00:00   272949.58590
# 2016-10-13 17:00:00   260058.91800
# 2016-10-13 18:00:00   178431.08590
# 2016-10-13 19:00:00        0.00000
# 2016-10-13 20:00:00        0.00000
# 2016-10-13 21:00:00        0.00000
# 2016-10-13 22:00:00        0.00000
# 2016-10-13 23:00:00        0.00000
# 2016-10-14 00:00:00        0.00000
# 2016-10-14 01:00:00        0.00000
# 2016-10-14 02:00:00        0.00000
# 2016-10-14 03:00:00        0.00000
# 2016-10-14 04:00:00        0.00000
# 2016-10-14 05:00:00        0.00000
# 2016-10-14 06:00:00        0.00000
# 2016-10-14 07:00:00        0.00000
# ...

# %%
# %matplotlib inline
Nichols['Demand(BTU/h)'].plot()

# %%
import matplotlib.pyplot as plt

# %%
Nichols['TimeStamp'].dt.hour
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-19fa4cac83c4> in <module>()
# ----> 1 Nichols['TimeStamp'].dt.hour
#
# /projects/sage/sage-7.5/local/lib/python2.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /projects/sage/sage-7.5/local/lib/python2.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /projects/sage/sage-7.5/local/lib/python2.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
# ...
