# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Numpy has a general statistic library for data analysis

# %%
Schulz = pd.read_csv('Schulz_clean_Nov.csv', parse_dates=True, index_col=0)

# %%
Schulz.columns
# Out:
# Index(['Demand(kW)'], dtype='object')

# %% [markdown]
# Finding information on the data, use 'np.' before the function name

# %%
np.mean(Schulz['Demand(kW)'])
# Out:
# 287.6420799411694

# %%
# %matplotlib inline
Schulz['Demand(kW)'].plot()

# %%
Schulz
